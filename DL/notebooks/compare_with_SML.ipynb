# %%
from tabulate import tabulate

# %%
data = [
    ["Perfomance", "Better", "Little bit worst"],
    ["Training Speed", "Slow", "Super Fast"],
    ["Complexity", "Easier", "Difficult"],
    ["Overfitted", "No", "No"],
    ["Interpretability", "High", "Low"],
]

headers = ["Feature", "SML", "SDL"]

table = tabulate(data, headers=headers, tablefmt="grid")

print(table)
# Out:
# +------------------+--------+------------------+
# | Feature          | SML    | SDL              |
# +==================+========+==================+
# | Perfomance       | Better | Little bit worst |
# +------------------+--------+------------------+
# | Training Speed   | Slow   | Super Fast       |
# +------------------+--------+------------------+
# | Complexity       | Easier | Difficult        |
# +------------------+--------+------------------+
# | Overfitted       | No     | No               |
# +------------------+--------+------------------+
# | Interpretability | High   | Low              |
# +------------------+--------+------------------+

# %%
'''
            AdaBoost Results                          
┏━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┓
┃ Algorithm      ┃ R2   ┃ MAE  ┃ MSE  ┃ RMSE ┃
┡━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━┩
│ AdaBoost       │ 0.81 │ 2.40 │ 7.66 │ 2.77 │
└────────────────┴──────┴──────┴──────┴──────┘

'''

# %%
'''
            Neural Network Results            
┏━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━┓
┃ Model         ┃ R2   ┃ MAE  ┃ MSE   ┃ RMSE ┃
┡━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━┩
│ NeuralNetwork │ 0.74 │ 2.82 │ 10.48 │ 3.24 │
└───────────────┴──────┴──────┴───────┴──────┘

'''
