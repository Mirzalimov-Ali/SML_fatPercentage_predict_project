# %%
import pandas as pd
import os
import numpy as np

# %%
os.chdir(r'C:\SML_Projects\SML_gym_fatPercentage_predict_project')

# %%
x_train = pd.read_csv('data/preprocessed/preprocessed_x_train.csv')
x_test = pd.read_csv('data/preprocessed/preprocessed_x_test.csv')

y_train = pd.read_csv('data/split/y_train.csv')['fat_percentage']
y_test = pd.read_csv('data/split/y_test.csv')['fat_percentage']

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %% [markdown]
# # Bu yerda base model training uchun umumiy "32ta" algorithm qollanilgan!

# %% [markdown]
# # ================================================

# %% [markdown]
# # 1. Linear Modellar oilasi
#
# `Jami: 11 ta`
#
# - Linear Regression
# - Lasso
# - Ridge
# - ElasticNet
# - Bayesian Ridge
# - ARD Regression
# - Huber Regressor
# - Theil-Sen Regressor
# - RANSAC Regressor
# - SGDRegressor
# - Passive-Aggressive Regressor

# %%
# LINEAR MODELS (11ta)
from sklearn.linear_model import (
    LinearRegression,
    Lasso,
    Ridge,
    ElasticNet,
    BayesianRidge,
    ARDRegression,
    HuberRegressor,
    TheilSenRegressor,
    RANSACRegressor,
    SGDRegressor,
    PassiveAggressiveRegressor
)

# %% [markdown]
# ## Linear Regression

# %%
lr = LinearRegression()

lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)

lr_score = r2_score(y_test, y_pred)

lr_mae = mean_absolute_error(y_test, y_pred)
lr_mse = mean_squared_error(y_test, y_pred)
lr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

lr_scores = cross_val_score(lr, x_train, y_train, cv=kf, scoring='r2')

print(f'Logistic Regression score: {lr_score}')

print(f'\nMAE: {lr_mae}')
print(f'MSE: {lr_mse}')
print(f'RMSE: {lr_rmse}')

print("\nK-Fold mean:", lr_scores.mean())
print("K-Fold std:", lr_scores.std())
# Out:
# Logistic Regression score: 0.7908847430929267
#
# MAE: 2.4853815359277283
# MSE: 8.287899705804016
# RMSE: 2.878871255510398
#
# K-Fold mean: 0.7932901328405046
# K-Fold std: 0.003636073702284104

# %% [markdown]
# ## Lasso

# %%
lasso = Lasso(alpha=0.0001, max_iter=500)

lasso.fit(x_train, y_train)
y_pred = lasso.predict(x_test)

lasso_score = r2_score(y_test, y_pred)

lasso_mae = mean_absolute_error(y_test, y_pred)
lasso_mse = mean_squared_error(y_test, y_pred)
lasso_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

lasso_scores = cross_val_score(lasso, x_train, y_train, cv=kf, scoring='r2')

print(f'Lasso score: {lasso_score}')

print(f'\nMAE: {lasso_mae}')
print(f'MSE: {lasso_mse}')
print(f'RMSE: {lasso_rmse}')

print("\nK-Fold mean:", lasso_scores.mean())
print("K-Fold std:", lasso_scores.std())
# Out:
# Lasso score: 0.7686947162759605
#
# MAE: 2.59080278570553
# MSE: 9.167360723848446
# RMSE: 3.027764971699165
#
# K-Fold mean: 0.7743152090980283
# K-Fold std: 0.007168660689032025
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.096e+03, tolerance: 3.034e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.988e+03, tolerance: 1.966e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# ## Ridge

# %%
ridge = Ridge(alpha=0.1, random_state=42)

ridge.fit(x_train, y_train)
y_pred = ridge.predict(x_test)

ridge_score = r2_score(y_test, y_pred)

ridge_mae = mean_absolute_error(y_test, y_pred)
ridge_mse = mean_squared_error(y_test, y_pred)
ridge_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

ridge_scores = cross_val_score(ridge, x_train, y_train, cv=kf, scoring='r2')

print(f'Ridge score: {ridge_score}')

print(f'\nMAE: {ridge_mae}')
print(f'MSE: {ridge_mse}')
print(f'RMSE: {ridge_rmse}')

print("\nK-Fold mean:", ridge_scores.mean())
print("K-Fold std:", ridge_scores.std())
# Out:
# Ridge score: 0.7903929365281746
#
# MAE: 2.4803226599432313
# MSE: 8.307391557061589
# RMSE: 2.8822545961558617
#
# K-Fold mean: 0.7932544513915163
# K-Fold std: 0.004110229844316554

# %% [markdown]
# ## ElasticNet

# %%
en = ElasticNet(alpha=0.001, l1_ratio=0.9, max_iter=5000, random_state=42)

en.fit(x_train, y_train)
y_pred = en.predict(x_test)

en_score = r2_score(y_test, y_pred)

en_mae = mean_absolute_error(y_test, y_pred)
en_mse = mean_squared_error(y_test, y_pred)
en_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

en_scores = cross_val_score(en, x_train, y_train, cv=kf, scoring='r2')

print(f'ElasticNet score: {en_score}')

print(f'\nMAE: {en_mae}')
print(f'MSE: {en_mse}')
print(f'RMSE: {en_rmse}')

print("\nK-Fold mean:", en_scores.mean())
print("K-Fold std:", en_scores.std())
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.390e+02, tolerance: 3.034e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.380e+02, tolerance: 1.966e+00
#   model = cd_fast.enet_coordinate_descent(
# ElasticNet score: 0.7905469378325611
#
# MAE: 2.4831828988080127
# MSE: 8.301287997789075
# RMSE: 2.88119558478578
#
# K-Fold mean: 0.7946090578116299
# K-Fold std: 0.004035178643039831
# ...

# %% [markdown]
# ## BayesianRidge

# %%
br = BayesianRidge(max_iter=300)

br.fit(x_train, y_train)
y_pred = br.predict(x_test)

br_score = r2_score(y_test, y_pred)

br_mae = mean_absolute_error(y_test, y_pred)
br_mse = mean_squared_error(y_test, y_pred)
br_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

br_scores = cross_val_score(br, x_train, y_train, cv=kf, scoring='r2')

print(f'BayesianRidge score: {br_score}')

print(f'\nMAE: {br_mae}')
print(f'MSE: {br_mse}')
print(f'RMSE: {br_rmse}')

print("\nK-Fold mean:", br_scores.mean())
print("K-Fold std:", br_scores.std())
# Out:
# BayesianRidge score: 0.7885953611553712
#
# MAE: 2.4915667768516805
# MSE: 8.378635160344146
# RMSE: 2.8945872176087812
#
# K-Fold mean: 0.7924118310151039
# K-Fold std: 0.004692718425997918

# %% [markdown]
# ## ARDRegression

# %%
ardr = ARDRegression(max_iter=300)

ardr.fit(x_train, y_train)
y_pred = ardr.predict(x_test)

ardr_score = r2_score(y_test, y_pred)

ardr_mae = mean_absolute_error(y_test, y_pred)
ardr_mse = mean_squared_error(y_test, y_pred)
ardr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

ardr_scores = cross_val_score(ardr, x_train, y_train, cv=kf, scoring='r2')

print(f'ARDRegression score: {ardr_score}')

print(f'\nMAE: {ardr_mae}')
print(f'MSE: {ardr_mse}')
print(f'RMSE: {ardr_rmse}')

print("\nK-Fold mean:", ardr_scores.mean())
print("K-Fold std:", ardr_scores.std())
# Out:
# ARDRegression score: 0.7995969408227033
#
# MAE: 2.432328331900862
# MSE: 7.942607726301969
# RMSE: 2.818263246451965
#
# K-Fold mean: 0.8028742528753071
# K-Fold std: 0.00298977487593558

# %% [markdown]
# ## HuberRegressor

# %%
huber = HuberRegressor(epsilon=1.35, max_iter=500)

huber.fit(x_train, y_train)
y_pred = huber.predict(x_test)

huber_score = r2_score(y_test, y_pred)

huber_mae = mean_absolute_error(y_test, y_pred)
huber_mse = mean_squared_error(y_test, y_pred)
huber_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

huber_scores = cross_val_score(huber, x_train, y_train, cv=kf, scoring='r2')

print(f'HuberRegressor score: {huber_score}')

print(f'\nMAE: {huber_mae}')
print(f'MSE: {huber_mse}')
print(f'RMSE: {huber_rmse}')

print("\nK-Fold mean:", huber_scores.mean())
print("K-Fold std:", huber_scores.std())
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_huber.py:348: ConvergenceWarning: lbfgs failed to converge after 500 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=500).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_huber.py:348: ConvergenceWarning: lbfgs failed to converge after 500 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=500).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# ## TheilSenRegressor

# %%
tsr = TheilSenRegressor(max_iter=300)

tsr.fit(x_train, y_train)
y_pred = tsr.predict(x_test)

tsr_score = r2_score(y_test, y_pred)

tsr_mae = mean_absolute_error(y_test, y_pred)
tsr_mse = mean_squared_error(y_test, y_pred)
tsr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

tsr_scores = cross_val_score(tsr, x_train, y_train, cv=kf, scoring='r2')

print(f'TheilSenRegressor score: {tsr_score}')

print(f'\nMAE: {tsr_mae}')
print(f'MSE: {tsr_mse}')
print(f'RMSE: {tsr_rmse}')

print("\nK-Fold mean:", tsr_scores.mean())
print("K-Fold std:", tsr_scores.std())
# Out:
# TheilSenRegressor score: 0.791397072906203
#
# MAE: 2.4794352940646602
# MSE: 8.267594453229286
# RMSE: 2.875342493204816
#
# K-Fold mean: 0.7898010684134865
# K-Fold std: 0.0035853791559129875

# %% [markdown]
# ## RANSACRegressor

# %%
ransacr = RANSACRegressor(min_samples=0.5, random_state=42)

ransacr.fit(x_train, y_train)
y_pred = ransacr.predict(x_test)

ransacr_score = r2_score(y_test, y_pred)

ransacr_mae = mean_absolute_error(y_test, y_pred)
ransacr_mse = mean_squared_error(y_test, y_pred)
ransacr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

ransacr_scores = cross_val_score(ransacr, x_train, y_train, cv=kf, scoring='r2')

print(f'RANSACRegressor score: {ransacr_score}')

print(f'\nMAE: {ransacr_mae}')
print(f'MSE: {ransacr_mse}')
print(f'RMSE: {ransacr_rmse}')

print("\nK-Fold mean:", ransacr_scores.mean())
print("K-Fold std:", ransacr_scores.std())
# Out:
# RANSACRegressor score: 0.7699143891815671
#
# MAE: 2.5232262400117142
# MSE: 9.119021225023422
# RMSE: 3.0197717173692817
#
# K-Fold mean: 0.7640578405875065
# K-Fold std: 0.003423115226597478

# %% [markdown]
# ## SGDRegressor

# %%
sgdr = SGDRegressor(loss="squared_error", alpha=1e-4, max_iter=3000, random_state=42)

sgdr.fit(x_train, y_train)
y_pred = sgdr.predict(x_test)

sgdr_score = r2_score(y_test, y_pred)

sgdr_mae = mean_absolute_error(y_test, y_pred)
sgdr_mse = mean_squared_error(y_test, y_pred)
sgdr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

sgdr_scores = cross_val_score(sgdr, x_train, y_train, cv=kf, scoring='r2')

print(f'SGDRegressor score: {sgdr_score}')

print(f'\nMAE: {sgdr_mae}')
print(f'MSE: {sgdr_mse}')
print(f'RMSE: {sgdr_rmse}')

print("\nK-Fold mean:", sgdr_scores.mean())
print("K-Fold std:", sgdr_scores.std())
# Out:
# SGDRegressor score: 0.7156722678646962
#
# MAE: 2.87295929639221
# MSE: 11.268808227432592
# RMSE: 3.3569045603699537
#
# K-Fold mean: 0.7258096515576978
# K-Fold std: 0.014119877279892019

# %% [markdown]
# ## PassiveAggressiveRegressor

# %%
par = PassiveAggressiveRegressor(C=1.0, max_iter=3000, random_state=42)

par.fit(x_train, y_train)
y_pred = par.predict(x_test)

par_score = r2_score(y_test, y_pred)

par_mae = mean_absolute_error(y_test, y_pred)
par_mse = mean_squared_error(y_test, y_pred)
par_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

par_scores = cross_val_score(par, x_train, y_train, cv=kf, scoring='r2')

print(f'PassiveAggressive score: {par_score}')

print(f'\nMAE: {par_mae}')
print(f'MSE: {par_mse}')
print(f'RMSE: {par_rmse}')

print("\nK-Fold mean:", par_scores.mean())
print("K-Fold std:", par_scores.std())
# Out:
# PassiveAggressive score: 0.20212009970274347
#
# MAE: 4.574680937853951
# MSE: 31.622506596346266
# RMSE: 5.623389244605629
#
# K-Fold mean: 0.4025816504659598
# K-Fold std: 0.11854885973118347

# %% [markdown]
# # 2. Tree-Based Modellar oilasi
#
# `Jami: 1 ta`
#
# - Decision Tree

# %%
# Tree MODELS (1ta)
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## DesicionTree

# %%
dt = DecisionTreeRegressor(max_depth=10, min_samples_split=5, random_state=42)

dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)

dt_score = r2_score(y_test, y_pred)

dt_mae = mean_absolute_error(y_test, y_pred)
dt_mse = mean_squared_error(y_test, y_pred)
dt_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

dt_scores = cross_val_score(dt, x_train, y_train, cv=kf, scoring='r2')

print(f'DecisionTree score: {dt_score}')

print(f'\nMAE: {dt_mae}')
print(f'MSE: {dt_mse}')
print(f'RMSE: {dt_rmse}')

print("\nK-Fold mean:", dt_scores.mean())
print("K-Fold std:", dt_scores.std())
# Out:
# DecisionTree score: 0.7097208975045738
#
# MAE: 2.7121072690070127
# MSE: 11.50467987728886
# RMSE: 3.3918549316397453
#
# K-Fold mean: 0.6646937495680026
# K-Fold std: 0.0060055942744146815

# %% [markdown]
# # 3. Ensemble Modellar oilasi
#
# `Jami: 14 ta`
#
# - Bagging oilasi (4):
#     - Random Forest
#     - Bagging
#     - Extra Trees
#     - Bagged DT
#
# - Boosting oilasi (7ta):
#     - Gradient Boosting
#     - Hist Gradient Boosting
#     - CatBoost
#     - AdaBoost
#     - XGBoost
#     - LightGBM
#     - NGBoost
#
# - Stacking
#
# - Voting

# %%
# Bagging MODELS (3ta)
from sklearn.ensemble import (
    RandomForestRegressor,
    BaggingRegressor,
    ExtraTreesRegressor
)

# %% [markdown]
# ## RandomForest

# %%
rf = RandomForestRegressor(n_estimators=500, max_depth=15, n_jobs=-1, random_state=42)

rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)

rf_score = r2_score(y_test, y_pred)

rf_mae = mean_absolute_error(y_test, y_pred)
rf_mse = mean_squared_error(y_test, y_pred)
rf_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

rf_scores = cross_val_score(rf, x_train, y_train, cv=kf, scoring='r2')

print(f'RandomForest score: {rf_score}')

print(f'\nMAE: {rf_mae}')
print(f'MSE: {rf_mse}')
print(f'RMSE: {rf_rmse}')

print("\nK-Fold mean:", rf_scores.mean())
print("K-Fold std:", rf_scores.std())
# Out:
# RandomForest score: 0.8002772398794226
#
# MAE: 2.4016339508963513
# MSE: 7.915645320806384
# RMSE: 2.813475665579211
#
# K-Fold mean: 0.7930444831738727
# K-Fold std: 0.0040861266003110385

# %% [markdown]
# ## Bagging

# %%
bag = BaggingRegressor(n_estimators=500, random_state=42)

bag.fit(x_train, y_train)
y_pred = bag.predict(x_test)

bag_score = r2_score(y_test, y_pred)

bag_mae = mean_absolute_error(y_test, y_pred)
bag_mse = mean_squared_error(y_test, y_pred)
bag_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

bag_scores = cross_val_score(bag, x_train, y_train, cv=kf, scoring='r2')

print(f'Bagging score: {bag_score}')

print(f'\nMAE: {bag_mae}')
print(f'MSE: {bag_mse}')
print(f'RMSE: {bag_rmse}')

print("\nK-Fold mean:", bag_scores.mean())
print("K-Fold std:", bag_scores.std())
# Out:
# Bagging score: 0.7996765155117429
#
# MAE: 2.4065292307692325
# MSE: 7.939453929435902
# RMSE: 2.8177036624591847
#
# K-Fold mean: 0.7924221047220764
# K-Fold std: 0.003836989539620453

# %% [markdown]
# ## Bagged DT

# %%
bag_dt = BaggingRegressor(
    estimator=DecisionTreeRegressor(max_depth=10),
    n_estimators=100,
    random_state=42
)

bag_dt.fit(x_train, y_train)
y_pred = bag_dt.predict(x_test)

bag_dt_score = r2_score(y_test, y_pred)

bag_dt_mae = mean_absolute_error(y_test, y_pred)
bag_dt_mse = mean_squared_error(y_test, y_pred)
bag_dt_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

bag_dt_scores = cross_val_score(bag_dt, x_train, y_train, cv=kf, scoring='r2')

print(f'Bagged DT score: {bag_dt_score}')

print(f'\nMAE: {bag_dt_mae}')
print(f'MSE: {bag_dt_mse}')
print(f'RMSE: {bag_dt_rmse}')

print("\nK-Fold mean:", bag_dt_scores.mean())
print("K-Fold std:", bag_dt_scores.std())
# Out:
# Bagged DT score: 0.8006171631126281
#
# MAE: 2.3959251701448867
# MSE: 7.902173086852014
# RMSE: 2.8110804127331566
#
# K-Fold mean: 0.7904733135328063
# K-Fold std: 0.004301206546253769

# %% [markdown]
# ## ExtraTree

# %%
et = ExtraTreesRegressor(n_estimators=500, max_depth=20, random_state=42)

et.fit(x_train, y_train)
y_pred = et.predict(x_test)

et_score = r2_score(y_test, y_pred)

et_mae = mean_absolute_error(y_test, y_pred)
et_mse = mean_squared_error(y_test, y_pred)
et_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

et_scores = cross_val_score(et, x_train, y_train, cv=kf, scoring='r2')

print(f'ExtraTrees score: {et_score}')

print(f'\nMAE: {et_mae}')
print(f'MSE: {et_mse}')
print(f'RMSE: {et_rmse}')

print("\nK-Fold mean:", et_scores.mean())
print("K-Fold std:", et_scores.std())
# Out:
# ExtraTrees score: 0.7954784408005373
#
# MAE: 2.4036293876814137
# MSE: 8.105836921660165
# RMSE: 2.8470751520920845
#
# K-Fold mean: 0.7851489733575218
# K-Fold std: 0.005297929042047186

# %%
# Boosting MODELS (6ta)
from sklearn.ensemble import (
    GradientBoostingRegressor,
    HistGradientBoostingRegressor,
    AdaBoostRegressor
)

from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from ngboost import NGBRegressor   # install

# %% [markdown]
# ## Gradient Boosting

# %%
gb = GradientBoostingRegressor(n_estimators=500, learning_rate=0.05, max_depth=5, random_state=42)

gb.fit(x_train, y_train)
y_pred = gb.predict(x_test)

gb_score = r2_score(y_test, y_pred)

gb_mae = mean_absolute_error(y_test, y_pred)
gb_mse = mean_squared_error(y_test, y_pred)
gb_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

gb_scores = cross_val_score(gb, x_train, y_train, cv=kf, scoring='r2')

print(f'GradientBoosting score: {gb_score}')

print(f'\nMAE: {gb_mae}')
print(f'MSE: {gb_mse}')
print(f'RMSE: {gb_rmse}')

print("\nK-Fold mean:", gb_scores.mean())
print("K-Fold std:", gb_scores.std())
# Out:
# GradientBoosting score: 0.770167430080819
#
# MAE: 2.5138543894044774
# MSE: 9.108992413039617
# RMSE: 3.018110735715245
#
# K-Fold mean: 0.761494314561987
# K-Fold std: 0.006963346694832697

# %% [markdown]
# ## Hist Gradient Boosting

# %%
hgb = HistGradientBoostingRegressor(max_iter=500, max_depth=7, random_state=42)

hgb.fit(x_train, y_train)
y_pred = hgb.predict(x_test)

hgb_score = r2_score(y_test, y_pred)

hgb_mae = mean_absolute_error(y_test, y_pred)
hgb_mse = mean_squared_error(y_test, y_pred)
hgb_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

hgb_scores = cross_val_score(hgb, x_train, y_train, cv=kf, scoring='r2')

print(f'HistGradientBoosting score: {hgb_score}')

print(f'\nMAE: {hgb_mae}')
print(f'MSE: {hgb_mse}')
print(f'RMSE: {hgb_rmse}')

print("\nK-Fold mean:", hgb_scores.mean())
print("K-Fold std:", hgb_scores.std())
# Out:
# HistGradientBoosting score: 0.7695604717075325
#
# MAE: 2.48322347445231
# MSE: 9.133048095048663
# RMSE: 3.022093329969917
#
# K-Fold mean: 0.7464895813291567
# K-Fold std: 0.016074661097333673

# %% [markdown]
# ## XGBoost

# %%
xgb= XGBRegressor(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="reg:squarederror",
    n_jobs=-1,
    random_state=42
)

xgb.fit(x_train, y_train)
y_pred = xgb.predict(x_test)

xgb_score = r2_score(y_test, y_pred)

xgb_mae = mean_absolute_error(y_test, y_pred)
xgb_mse = mean_squared_error(y_test, y_pred)
xgb_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

xgb_scores = cross_val_score(xgb, x_train, y_train, cv=kf, scoring='r2')

print(f'XGBoost score: {xgb_score}')

print(f'\nMAE: {xgb_mae}')
print(f'MSE: {xgb_mse}')
print(f'RMSE: {xgb_rmse}')

print("\nK-Fold mean:", xgb_scores.mean())
print("K-Fold std:", xgb_scores.std())
# Out:
# XGBoost score: 0.7781535123696046
#
# MAE: 2.45318721086551
# MSE: 8.792478687399955
# RMSE: 2.9652114068646025
#
# K-Fold mean: 0.7720746727970241
# K-Fold std: 0.008451321478491057

# %% [markdown]
# ## AdaBoost

# %%
ab = AdaBoostRegressor(n_estimators=300, learning_rate=0.05, random_state=42)

ab.fit(x_train, y_train)
y_pred = ab.predict(x_test)

ab_score = r2_score(y_test, y_pred)

ab_mae = mean_absolute_error(y_test, y_pred)
ab_mse = mean_squared_error(y_test, y_pred)
ab_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

ab_scores = cross_val_score(ab, x_train, y_train, cv=kf, scoring='r2')

print(f'AdaBoost score: {ab_score}')

print(f'\nMAE: {ab_mae}')
print(f'MSE: {ab_mse}')
print(f'RMSE: {ab_rmse}')

print("\nK-Fold mean:", ab_scores.mean())
print("K-Fold std:", ab_scores.std())
# Out:
# AdaBoost score: 0.8067452028845445
#
# MAE: 2.399496993037608
# MSE: 7.659299468857748
# RMSE: 2.7675439416308727
#
# K-Fold mean: 0.8091310212321403
# K-Fold std: 0.004144201974802363

# %% [markdown]
# ## LightGBM

# %%
lgbm = LGBMRegressor(n_estimators=500, learning_rate=0.05, num_leaves=31, subsample=0.8, colsample_bytree=0.8, random_state=42)

lgbm.fit(x_train, y_train)
y_pred = lgbm.predict(x_test)

lgbm_score = r2_score(y_test, y_pred)

lgbm_mae = mean_absolute_error(y_test, y_pred)
lgbm_mse = mean_squared_error(y_test, y_pred)
lgbm_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

lgbm_scores = cross_val_score(lgbm, x_train, y_train, cv=kf, scoring='r2')

print(f'LightGBM score: {lgbm_score}')

print(f'\nMAE: {lgbm_mae}')
print(f'MSE: {lgbm_mse}')
print(f'RMSE: {lgbm_rmse}')

print("\nK-Fold mean:", lgbm_scores.mean())
print("K-Fold std:", lgbm_scores.std())
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5098
# [LightGBM] [Info] Number of data points in the train set: 778, number of used features: 35
# [LightGBM] [Info] Start training from score 25.033419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# ## CatBoost

# %%
cat = CatBoostRegressor(iterations=500, depth=8,learning_rate=0.05, verbose=False, random_state=42)

cat.fit(x_train, y_train)
y_pred = cat.predict(x_test)

cat_score = r2_score(y_test, y_pred)

cat_mae = mean_absolute_error(y_test, y_pred)
cat_mse = mean_squared_error(y_test, y_pred)
cat_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

cat_scores = cross_val_score(cat, x_train, y_train, cv=kf, scoring='r2')

print(f'CatBoost score: {cat_score}')

print(f'\nMAE: {cat_mae}')
print(f'MSE: {cat_mse}')
print(f'RMSE: {cat_rmse}')

print("\nK-Fold mean:", cat_scores.mean())
print("K-Fold std:", cat_scores.std())
# Out:
# CatBoost score: 0.78581639589243
#
# MAE: 2.4615732627959566
# MSE: 8.48877435212681
# RMSE: 2.913550128644917
#
# K-Fold mean: 0.7868526775251131
# K-Fold std: 0.005595787573451324

# %% [markdown]
# ## NGBRegressor

# %%
ngbr = NGBRegressor(n_estimators=500, learning_rate=0.03, random_state=42)

ngbr.fit(x_train, y_train)
y_pred = ngbr.predict(x_test)

ngbr_score = r2_score(y_test, y_pred)

ngbr_mae = mean_absolute_error(y_test, y_pred)
ngbr_mse = mean_squared_error(y_test, y_pred)
ngbr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

ngbr_scores = cross_val_score(ngbr, x_train, y_train, cv=kf, scoring='r2')

print(f'NGBRegressor score: {ngbr_score}')

print(f'\nMAE: {ngbr_mae}')
print(f'MSE: {ngbr_mse}')
print(f'RMSE: {ngbr_rmse}')

print("\nK-Fold mean:", ngbr_scores.mean())
print("K-Fold std:", ngbr_scores.std())
# Out:
# [iter 0] loss=3.2507 val_loss=0.0000 scale=2.0000 norm=10.1226
# [iter 100] loss=2.1472 val_loss=0.0000 scale=1.0000 norm=2.0016
# [iter 200] loss=2.0011 val_loss=0.0000 scale=1.0000 norm=1.8160
# [iter 300] loss=1.8660 val_loss=0.0000 scale=0.5000 norm=0.8255
# [iter 400] loss=1.7444 val_loss=0.0000 scale=1.0000 norm=1.5001
# [iter 0] loss=3.2370 val_loss=0.0000 scale=2.0000 norm=9.8557
# [iter 100] loss=2.0253 val_loss=0.0000 scale=1.0000 norm=1.7984
# [iter 200] loss=1.7894 val_loss=0.0000 scale=1.0000 norm=1.5415
# [iter 300] loss=1.5992 val_loss=0.0000 scale=1.0000 norm=1.3295
# [iter 400] loss=1.4743 val_loss=0.0000 scale=0.5000 norm=0.6058
# [iter 0] loss=3.2493 val_loss=0.0000 scale=2.0000 norm=10.1678
# [iter 100] loss=2.0730 val_loss=0.0000 scale=2.0000 norm=3.7649
# [iter 200] loss=1.8539 val_loss=0.0000 scale=1.0000 norm=1.6131
# [iter 300] loss=1.6944 val_loss=0.0000 scale=0.5000 norm=0.7199
# [iter 400] loss=1.5587 val_loss=0.0000 scale=1.0000 norm=1.2984
# ...

# %%
# Stacking & Voting MODELS
from sklearn.ensemble import (
    StackingRegressor,
    VotingRegressor
)

# %% [markdown]
# ## Stacking

# %%
base1 = RandomForestRegressor(random_state=42)
base2 = ExtraTreesRegressor(random_state=42)
base3 = LinearRegression()

stacking = StackingRegressor(
    estimators=[
        ('rf', base1),
        ('et', base2),
        ('lr', base3)
    ],
    final_estimator=LinearRegression()
)

stacking.fit(x_train, y_train)
y_pred = stacking.predict(x_test)

stacking_score = r2_score(y_test, y_pred)

stacking_mae = mean_absolute_error(y_test, y_pred)
stacking_mse = mean_squared_error(y_test, y_pred)
stacking_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

stacking_scores = cross_val_score(stacking, x_train, y_train, cv=kf, scoring='r2')

print(f'Stacking score: {stacking_score}')

print(f'\nMAE: {stacking_mae}')
print(f'MSE: {stacking_mse}')
print(f'RMSE: {stacking_rmse}')

print("\nK-Fold mean:", stacking_scores.mean())
print("K-Fold std:", stacking_scores.std())
# Out:
# Stacking score: 0.8002530327198366
#
# MAE: 2.4121699597988946
# MSE: 7.916604727182456
# RMSE: 2.813646162398971
#
# K-Fold mean: 0.795509192232347
# K-Fold std: 0.00571880898542205

# %% [markdown]
# # Voting

# %%
model1 = RandomForestRegressor(random_state=42)
model2 = ExtraTreesRegressor(random_state=42)
model3 = LinearRegression()

voting = VotingRegressor(
    estimators=[
        ('rf', model1),
        ('et', model2),
        ('lr', model3)
    ],
)

voting.fit(x_train, y_train)
y_pred = voting.predict(x_test)

voting_score = r2_score(y_test, y_pred)

voting_mae = mean_absolute_error(y_test, y_pred)
voting_mse = mean_squared_error(y_test, y_pred)
voting_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

voting_scores = cross_val_score(voting, x_train, y_train, cv=kf, scoring='r2')

print(f'Voting score: {voting_score}')

print(f'\nMAE: {voting_mae}')
print(f'MSE: {voting_mse}')
print(f'RMSE: {voting_rmse}')

print("\nK-Fold mean:", voting_scores.mean())
print("K-Fold std:", voting_scores.std())
# Out:
# Voting score: 0.8003620184605204
#
# MAE: 2.405013382309686
# MSE: 7.912285277222138
# RMSE: 2.8128784682638064
#
# K-Fold mean: 0.7952467340732011
# K-Fold std: 0.004231705141660897

# %% [markdown]
# # 4. Neighbors Modellar oilasi
#
# `Jami: 2 ta`
#
# - KNN Regressor
# - Radius Neighbors Regressor

# %%
# Keighbors MODELS (2ta)
from sklearn.neighbors import (
    KNeighborsRegressor,
    RadiusNeighborsRegressor,
)

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsRegressor(n_neighbors=1)

knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)

knn_score = r2_score(y_test, y_pred)

knn_mae = mean_absolute_error(y_test, y_pred)
knn_mse = mean_squared_error(y_test, y_pred)
knn_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

knn_scores = cross_val_score(knn, x_train, y_train, cv=kf, scoring='r2')

print(f'KNN score: {knn_score}')

print(f'\nMAE: {knn_mae}')
print(f'MSE: {knn_mse}')
print(f'RMSE: {knn_rmse}')

print("\nK-Fold mean:", knn_scores.mean())
print("K-Fold std:", knn_scores.std())
# Out:
# KNN score: 0.609659994683392
#
# MAE: 3.1246153846153844
# MSE: 15.470410256410256
# RMSE: 3.9332442406250663
#
# K-Fold mean: 0.5461159042300409
# K-Fold std: 0.04574089475134714

# %% [markdown]
# ## RNN

# %%
# rnn = RadiusNeighborsRegressor(radius=2.0, weights="distance")

# rnn.fit(x_train, y_train)
# y_pred = rnn.predict(x_test)

# rnn_score = r2_score(y_test, y_pred)

# rnn_mae = mean_absolute_error(y_test, y_pred)
# rnn_mse = mean_squared_error(y_test, y_pred)
# rnn_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

# rnn_scores = cross_val_score(rnn, x_train, y_train, cv=kf, scoring='r2')

# print(f'RNN score: {rnn_score}')

# print(f'\nMAE: {rnn_mae}')
# print(f'MSE: {rnn_mse}')
# print(f'RMSE: {rnn_rmse}')

# print("\nK-Fold mean:", rnn_scores.mean())
# print("K-Fold std:", rnn_scores.std())

# %% [markdown]
# # 5. SVM Modellar oilasi
#
# `Jami: 1 ta`
#
# - SVR

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR

svr = SVR(kernel='rbf', C=20.0, epsilon=0.1)

svr.fit(x_train, y_train)
y_pred = svr.predict(x_test)

svr_score = r2_score(y_test, y_pred)

svr_mae = mean_absolute_error(y_test, y_pred)
svr_mse = mean_squared_error(y_test, y_pred)
svr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

svr_scores = cross_val_score(svr, x_train, y_train, cv=kf, scoring='r2')

print(f'SVR score: {svr_score}')

print(f'\nMAE: {svr_mae}')
print(f'MSE: {svr_mse}')
print(f'RMSE: {svr_rmse}')

print("\nK-Fold mean:", svr_scores.mean())
print("K-Fold std:", svr_scores.std())
# Out:
# SVR score: 0.6851888740001899
#
# MAE: 2.9281648626630314
# MSE: 12.476961638992702
# RMSE: 3.532274287055395
#
# K-Fold mean: 0.7266136344695854
# K-Fold std: 0.006163886967374937

# %% [markdown]
# # 6. kernel-Based Modellar oilasi
#
# `Jami: 2 ta`
#
# - KernelRidge
# - GaussianProcessRegressor

# %%
# Kernel-Based MODELS (2ta)
from sklearn.kernel_ridge import KernelRidge
from sklearn.gaussian_process import GaussianProcessRegressor

# %% [markdown]
# ## KernelRidge

# %%
kr = KernelRidge(alpha=1.0, kernel="rbf")

kr.fit(x_train, y_train)
y_pred = kr.predict(x_test)

kr_score = r2_score(y_test, y_pred)

kr_mae = mean_absolute_error(y_test, y_pred)
kr_mse = mean_squared_error(y_test, y_pred)
kr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

kr_scores = cross_val_score(kr, x_train, y_train, cv=kf, scoring='r2')

print(f'KernelRidge score: {kr_score}')

print(f'\nMAE: {kr_mae}')
print(f'MSE: {kr_mse}')
print(f'RMSE: {kr_rmse}')

print("\nK-Fold mean:", kr_scores.mean())
print("K-Fold std:", kr_scores.std())
# Out:
# KernelRidge score: 0.6137248060590431
#
# MAE: 3.1946547188893244
# MSE: 15.30930891209573
# RMSE: 3.912711197123515
#
# K-Fold mean: 0.6507394027614887
# K-Fold std: 0.03349684124127987

# %% [markdown]
# ## GaussianProcessRegressor

# %%
gpr = GaussianProcessRegressor(normalize_y=True)

gpr.fit(x_train, y_train)
y_pred = gpr.predict(x_test)

gpr_score = r2_score(y_test, y_pred)

gpr_mae = mean_absolute_error(y_test, y_pred)
gpr_mse = mean_squared_error(y_test, y_pred)
gpr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

gpr_scores = cross_val_score(gpr, x_train, y_train, cv=kf, scoring='r2')

print(f'GaussianProcess score: {gpr_score}')

print(f'\nMAE: {gpr_mae}')
print(f'MSE: {gpr_mse}')
print(f'RMSE: {gpr_rmse}')

print("\nK-Fold mean:", gpr_scores.mean())
print("K-Fold std:", gpr_scores.std())
# Out:
# GaussianProcess score: 0.15892783883222894
#
# MAE: 4.746027571039367
# MSE: 33.334352644579965
# RMSE: 5.773590966164815
#
# K-Fold mean: 0.12116183848595526
# K-Fold std: 0.016762755143279146

# %% [markdown]
# # 7. Neural Network Modellar oilasi
#
# `Jami: 1 ta`
#
# - MLPRegressor

# %%
# Neural Network MODEL
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# ## MLPRegressor

# %%
mlpr = MLPRegressor(hidden_layer_sizes=(128, 64), activation="relu", max_iter=300, random_state=42)

mlpr.fit(x_train, y_train)
y_pred = mlpr.predict(x_test)

mlpr_score = r2_score(y_test, y_pred)

mlpr_mae = mean_absolute_error(y_test, y_pred)
mlpr_mse = mean_squared_error(y_test, y_pred)
mlpr_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

mlpr_scores = cross_val_score(mlpr, x_train, y_train, cv=kf, scoring='r2')

print(f'MLPRegressor score: {mlpr_score}')

print(f'\nMAE: {mlpr_mae}')
print(f'MSE: {mlpr_mse}')
print(f'RMSE: {mlpr_rmse}')

print("\nK-Fold mean:", mlpr_scores.mean())
print("K-Fold std:", mlpr_scores.std())
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor score: 0.7083926273579333
#
# MAE: 2.70368975423014
# MSE: 11.557323428603064
# RMSE: 3.399606363772586
#
# K-Fold mean: 0.6675470376926645
# K-Fold std: 0.0033932025604758594
# ...

# %% [markdown]
# # 8. Naive & Simple Modellar oilasi
#
# `Jami: 1 ta`
#
# - DummyRegressor

# %%
# Simple Baseline MODEL
from sklearn.dummy import DummyRegressor

# %% [markdown]
# ## DummyRegressor

# %%
dummy = DummyRegressor()

dummy.fit(x_train, y_train)
y_pred = dummy.predict(x_test)

dummy_score = r2_score(y_test, y_pred)

dummy_mae = mean_absolute_error(y_test, y_pred)
dummy_mse = mean_squared_error(y_test, y_pred)
dummy_rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

dummy_scores = cross_val_score(dummy, x_train, y_train, cv=kf, scoring='r2')

print(f'Dummy score: {dummy_score}')

print(f'\nMAE: {dummy_mae}')
print(f'MSE: {dummy_mse}')
print(f'RMSE: {dummy_rmse}')

print("\nK-Fold mean:", dummy_scores.mean())
print("K-Fold std:", dummy_scores.std())
# Out:
# Dummy score: -0.002015758846366955
#
# MAE: 5.1321257662645845
# MSE: 39.713056980075805
# RMSE: 6.3018296533686
#
# K-Fold mean: -0.00018208181036016846
# K-Fold std: 0.00012442349603421942

# %%
from rich.table import Table
from rich.console import Console

console = Console()

results = [
    # Linear Family
    ['Linear Regression', lr_score, lr_mae, lr_mse, lr_rmse, lr_scores.mean(), lr_scores.std()],
    ['Lasso', lasso_score, lasso_mae, lasso_mse, lasso_rmse, lasso_scores.mean(), lasso_scores.std()],
    ['Ridge', ridge_score, ridge_mae, ridge_mse, ridge_rmse, ridge_scores.mean(), ridge_scores.std()],
    ['ElasticNet', en_score, en_mae, en_mse, en_rmse, en_scores.mean(), en_scores.std()],
    ['Bayesian Ridge', br_score, br_mae, br_mse, br_rmse, br_scores.mean(), br_scores.std()],
    ['ARDR', ardr_score, ardr_mae, ardr_mse, ardr_rmse, ardr_scores.mean(), ardr_scores.std()],
    ['HuberR', huber_score, huber_mae, huber_mse, huber_rmse, huber_scores.mean(), huber_scores.std()],
    ['TheilSenR', tsr_score, tsr_mae, tsr_mse, tsr_rmse, tsr_scores.mean(), tsr_scores.std()],
    ['RANSACR', ransacr_score, ransacr_mae, ransacr_mse, ransacr_rmse, ransacr_scores.mean(), ransacr_scores.std()],
    ['SGDR', sgdr_score, sgdr_mae, sgdr_mse, sgdr_rmse, sgdr_scores.mean(), sgdr_scores.std()],
    ['Passive Aggressive', par_score, par_mae, par_mse, par_rmse, par_scores.mean(), par_scores.std()],

    # Tree-Based Family
    ['Decision Tree', dt_score, dt_mae, dt_mse, dt_rmse, dt_scores.mean(), dt_scores.std()],

    # Bagging Family
    ['Random Forest', rf_score, rf_mae, rf_mse, rf_rmse, rf_scores.mean(), rf_scores.std()],
    ['Bagging', bag_score, bag_mae, bag_mse, bag_rmse, bag_scores.mean(), bag_scores.std()],
    ['Bagged DT', bag_dt_score, bag_dt_mae, bag_dt_mse, bag_dt_rmse, bag_dt_scores.mean(), bag_dt_scores.std()],
    ['Extra Trees', et_score, et_mae, et_mse, et_rmse, et_scores.mean(), et_scores.std()],

    # Boosting Family
    ['Gradient Boosting', gb_score, gb_mae, gb_mse, gb_rmse, gb_scores.mean(), gb_scores.std()],
    ['Hist Gradient Boosting', hgb_score, hgb_mae, hgb_mse, hgb_rmse, hgb_scores.mean(), hgb_scores.std()],
    ['XGBoost', xgb_score, xgb_mae, xgb_mse, xgb_rmse, xgb_scores.mean(), xgb_scores.std()],
    ['AdaBoost', ab_score, ab_mae, ab_mse, ab_rmse, ab_scores.mean(), ab_scores.std()],
    ['LightGBM', lgbm_score, lgbm_mae, lgbm_mse, lgbm_rmse, lgbm_scores.mean(), lgbm_scores.std()],
    ['Cat Boost', cat_score, cat_mae, cat_mse, cat_rmse, cat_scores.mean(), cat_scores.std()],
    ['NGBRegressor', ngbr_score, ngbr_mae, ngbr_mse, ngbr_rmse, ngbr_scores.mean(), ngbr_scores.std()],

    # Stacking & Voting Family
    ['Voting', voting_score, voting_mae, voting_mse, voting_rmse, voting_scores.mean(), voting_scores.std()],
    ['Stacking', stacking_score, stacking_mae, stacking_mse, stacking_rmse, stacking_scores.mean(), stacking_scores.std()],

    # Neighbors Family
    ['KNN', knn_score, knn_mae, knn_mse, knn_rmse, knn_scores.mean(), knn_scores.std()],
    # ['RNN', rnn_score, rnn_mae, rnn_mse, rnn_rmse, rnn_scores.mean(), rnn_scores.std()],

    # SVM Family
    ['SVR', svr_score, svr_mae, svr_mse, svr_rmse, svr_scores.mean(), svr_scores.std()],

    # Kernel-Based Family
    ['Kernel Ridge', kr_score, kr_mae, kr_mse, kr_rmse, kr_scores.mean(), kr_scores.std()],
    ['Gaussian Process', gpr_score, gpr_mae, gpr_mse, gpr_rmse, gpr_scores.mean(), gpr_scores.std()],

    # Neural Network Family
    ['MLPR', mlpr_score, mlpr_mae, mlpr_mse, mlpr_rmse, mlpr_scores.mean(), mlpr_scores.std()],

    # Naive & Simple Family
    ['DummyRegressor', dummy_score, dummy_mae, dummy_mse, dummy_rmse, dummy_scores.mean(), dummy_scores.std()],
]

result_sorted = sorted(results, key=lambda i: i[1], reverse=True)

best_model = max(results, key=lambda x: x[1])
worst_model = min(results, key=lambda x: x[1])

table = Table(title="Comparison with feature engineering", show_lines=True)
table.add_column("Algorithm")
table.add_column("R2_Score")
table.add_column("MAE")
table.add_column("MSE")
table.add_column("RMSE")
table.add_column("K-Fold mean")
table.add_column("K-Fold std")

for row in result_sorted:
    algo, r2, mae, mse, rmse, kmean, kstd = row

    if row == best_model:
        table.add_row(
            f"[bold green]{algo}[/bold green]",
            f"[bold green]{r2:.2f}[/bold green]",
            f"[bold green]{mae:.2f}[/bold green]",
            f"[bold green]{mse:.2f}[/bold green]",
            f"[bold green]{rmse:.2f}[/bold green]",
            f"[bold green]{kmean:.2f}[/bold green]",
            f"[bold green]{kstd:.2f}[/bold green]",
        )
    elif row == worst_model:
        table.add_row(
            f"[bold red]{algo}[/bold red]",
            f"[bold red]{r2:.2f}[/bold red]",
            f"[bold red]{mae:.2f}[/bold red]",
            f"[bold red]{mse:.2f}[/bold red]",
            f"[bold red]{rmse:.2f}[/bold red]",
            f"[bold red]{kmean:.2f}[/bold red]",
            f"[bold red]{kstd:.2f}[/bold red]",
        )
    else:
        table.add_row(algo, f"{r2:.2f}", f"{mae:.2f}", f"{mse:.2f}", f"{rmse:.2f}", f"{kmean:.2f}", f"{kstd:.2f}")

console.print(table)
# Out:
#                          Comparison with feature engineering
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Algorithm              ┃ R2_Score ┃ MAE  ┃ MSE   ┃ RMSE ┃ K-Fold mean ┃ K-Fold std ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ AdaBoost               │ 0.81     │ 2.40 │ 7.66  │ 2.77 │ 0.81        │ 0.00       │
# ├────────────────────────┼──────────┼──────┼───────┼──────┼─────────────┼────────────┤
# │ Bagged DT              │ 0.80     │ 2.40 │ 7.90  │ 2.81 │ 0.79        │ 0.00       │
# ├────────────────────────┼──────────┼──────┼───────┼──────┼─────────────┼────────────┤
# │ Voting                 │ 0.80     │ 2.41 │ 7.91  │ 2.81 │ 0.80        │ 0.00       │
# ├────────────────────────┼──────────┼──────┼───────┼──────┼─────────────┼────────────┤
# │ Random Forest          │ 0.80     │ 2.40 │ 7.92  │ 2.81 │ 0.79        │ 0.00       │
# ...

# %%
os.makedirs('results', exist_ok=True)

temp_console = Console(record=True)
temp_console.print(table)
text = temp_console.export_text()
with open('results/FS_compare.txt', 'a', encoding='utf-8') as f:
    f.write(text)
# Out:
#                          Comparison with feature engineering
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Algorithm              ┃ R2_Score ┃ MAE  ┃ MSE   ┃ RMSE ┃ K-Fold mean ┃ K-Fold std ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ AdaBoost               │ 0.81     │ 2.40 │ 7.66  │ 2.77 │ 0.81        │ 0.00       │
# ├────────────────────────┼──────────┼──────┼───────┼──────┼─────────────┼────────────┤
# │ Bagged DT              │ 0.80     │ 2.40 │ 7.90  │ 2.81 │ 0.79        │ 0.00       │
# ├────────────────────────┼──────────┼──────┼───────┼──────┼─────────────┼────────────┤
# │ Voting                 │ 0.80     │ 2.41 │ 7.91  │ 2.81 │ 0.80        │ 0.00       │
# ├────────────────────────┼──────────┼──────┼───────┼──────┼─────────────┼────────────┤
# │ Random Forest          │ 0.80     │ 2.40 │ 7.92  │ 2.81 │ 0.79        │ 0.00       │
# ...

# %% [markdown]
# # Next step - Feature selection

# %% [markdown]
# <a href="FS/without_fs.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Without Feature selection
#     </button>
# </a>
#
# <a href="FS/filter.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Filter method
#     </button>
# </a>
#
# <a href="FS/embedded.ipynb" target="_blank" style="text-decoration: none;">
#     <button style="
#         background-color: #45a049;
#         color: white;
#         padding: 12px 24px;
#         font-size: 16px;
#         border: none;
#         border-radius: 8px;
#         cursor: pointer;
#         transition: background-color 0.3s;
#     " onmouseover="this.style.backgroundColor='#45a049'" onmouseout="this.style.backgroundColor='#4CAF50'">
#         Embedded method
#     </button>
# </a>
